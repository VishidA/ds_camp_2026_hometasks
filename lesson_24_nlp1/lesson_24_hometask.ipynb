# %%
from nltk.corpus import gutenberg , words
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.probability import FreqDist
import numpy as np


for pack in ['gutenberg', 'punkt_tab', 'averaged_perceptron_tagger', 'averaged_perceptron_tagger_eng', 'words']:
    nltk.download(pack, quiet=True)

moby_raw = gutenberg.raw('melville-moby_dick.txt')

# %% [markdown]
# # Question 1
#
# What is the lexical diversity of the given text input? (i.e. ratio of unique tokens to the total number of tokens)
# This function should return a float.

# %%
def answer_one():
    tokens = word_tokenize(moby_raw)
    return len(set(tokens)) / len(tokens)

# %%
answer_one()
# Out:
# 0.08086685317096488

# %% [markdown]
# # Question 2
#
# What percentage of tokens is 'whale'or 'Whale'?
# This function should return a float.

# %%
def answer_two(): 
    tokens = word_tokenize(moby_raw)
    result = tokens.count("whale") + tokens.count("Whale") 
    return (result * 100) / len(tokens)

# %%
answer_two()
# Out:
# 0.4157165134667074

# %% [markdown]
# # Question 3
#
# What are the 20 most frequently occurring (unique) tokens in the text? What is their frequency?
# This function should return a list of 10 tuples where each tuple is of the form (token, frequency). The list should be sorted in descending order of frequency

# %%
def answer_three():
    tokens = word_tokenize(moby_raw)
    dist = FreqDist(tokens)
    return dist.most_common(10)

# %%
answer_three()
# Out:
# [(',', 19204),
#  ('the', 13715),
#  ('.', 7306),
#  ('of', 6513),
#  ('and', 6010),
#  ('a', 4545),
#  ('to', 4515),
#  (';', 4173),
#  ('in', 3908),
#  ('that', 2981)]

# %% [markdown]
# # Question 4
#
# What tokens have a length of greater than 5 and frequency of more than 150?
# This function should return a sorted list of the tokens that match the above constraints. To sort your list, use sorted()

# %%
def answer_four():
    tokens = word_tokenize(moby_raw)
    dist = FreqDist(tokens)
    filtered_tokens = [token for token, freq in dist.items() if len(token) > 5 and freq > 150]
    return sorted(filtered_tokens)

# %%
print (answer_four())
# Out:
# ['Captain', 'Pequod', 'Queequeg', 'Starbuck', 'almost', 'before', 'himself', 'little', 'seemed', 'should', 'though', 'through', 'whales', 'without']

# %% [markdown]
# # Question 5
#
# Find the longest word in text1 and that word's length.
# This function should return a tuple (longest_word, length).

# %%
def answer_five():
    tokens = word_tokenize(moby_raw)
    longest_word = max(tokens, key=len)
    return (longest_word, len(longest_word))

# %%
answer_five()
# Out:
# ("twelve-o'clock-at-night", 23)

# %% [markdown]
# # Question 6
#
# What unique words have a frequency of more than 2000? What is their frequency?
# This function should return a list of tuples of the form (frequency, word) sorted in descending order of frequency.

# %%
def answer_six():
    tokens = word_tokenize(moby_raw)
    dist = FreqDist(tokens)
    freq_words = [(freq, token) for token, freq in dist.items() if freq > 2000 and token.isalpha()]
    return sorted(freq_words, reverse=True)

# %%
print(answer_six())
# Out:
# [(13715, 'the'), (6513, 'of'), (6010, 'and'), (4545, 'a'), (4515, 'to'), (3908, 'in'), (2981, 'that'), (2459, 'his'), (2206, 'it'), (2121, 'I')]

# %% [markdown]
# # Question 7
#
# What is the average number of tokens per sentence?
# This function should return a float.

# %%
def answer_seven():
    sentences = sent_tokenize(moby_raw)
    tokens = word_tokenize(moby_raw)

    return len(tokens) / len(sentences)

# %%
print(answer_seven())
# Out:
# 25.90560292326431

# %% [markdown]
# # Question 8
#
# What are the 5 most frequent parts of speech in this text? What is their frequency?
# This function should return a list of tuples of the form (part_of_speech, frequency) sorted in descending order of frequency.

# %%
def answer_eight():
    tokens = word_tokenize(moby_raw)
    tagged_tokens = nltk.pos_tag(tokens)
    tags = [tag for _, tag in tagged_tokens]
    dist = FreqDist(tags)
    return dist.most_common(5)

# %%
print(answer_eight())
# Out:
# [('NN', 32722), ('IN', 28659), ('DT', 25885), (',', 19204), ('JJ', 17598)]

# %% [markdown]
# # Question 9
#
# Create spelling recommender, that take a list of misspelled words and recommends a correctly spelled word for every word in the list.
#
# For every misspelled word, the recommender should find find the word in correct_spellings that has the shortest edit distance (you may need to use nltk.edit_distance(word_1, word_2, transpositions=True)), and starts with the same letter as the misspelled word, and return that word as a recommendation.
#
# Recommender should provide recommendations for the three words: ['cormulent', 'incendenece', 'validrate'].
# This function should return a list of length three: ['cormulent_reccomendation', 'incendenece_reccomendation', 'validrate_reccomendation']

# %%
def answer_nine(default_words= ['cormulent', 'incendenece', 'validrate']):
    recommendations = []
    correct_spellings = words.words()
    
    for entry in default_words:
        valid_words = [word for word in correct_spellings if word[0].lower() == entry[0].lower()]
        
        best_match = min(
            valid_words, 
            key=lambda word: nltk.edit_distance(entry, word, transpositions=True)
        )
        
        recommendations.append(best_match)
        
    return recommendations

# %%
answer_nine()
# Out:
# ['corpulent', 'intendence', 'validate']
